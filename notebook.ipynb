# %%
from google.colab import drive; drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/richiexuetang/recsys.git
# Out:
# Cloning into 'recsys'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8 (delta 0), reused 8 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), 8.48 KiB | 8.48 MiB/s, done.

# %%
# !cd recsys/

# %%
# !pip install huggingface_hub
# !hf download reczoo/TaobaoAd_x1 --repo-type dataset --local-dir ./raw
# Out:
# ...
# Fetching 3 files:  33% 1/3 [00:00<00:00,  7.08it/s]Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# ...
# Fetching 3 files: 100% 3/3 [00:10<00:00,  3.55s/it]
# Download complete: 100% 2.44G/2.44G [00:10<00:00, 323MB/s]                ✓ Downloaded
#   path: /content/raw
# Download complete: 100% 2.44G/2.44G [00:10<00:00, 229MB/s]

# %%
import zipfile
import pandas as pd

# 1. Extract the zip file
with zipfile.ZipFile('/content/recsys/raw/TaobaoAd_x1.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/recsys/raw/')

# 2. Read the extracted file (e.g., CSV) into a DataFrame
test_df = pd.read_csv('/content/recsys/raw/test.csv')
train_df = pd.read_csv('/content/recsys/raw/train.csv')

# 3. Convert and save as Parquet
test_df.to_parquet('/content/recsys/raw/test.parquet', index=False)
train_df.to_parquet('/content/recsys/raw/train.parquet', index=False)

# %%
# !python /content/recsys/prep/prepare_data.py --raw /content/recsys/raw/train.parquet --out /content/recsys/build --max-rows 2000000
# Out:
# [load] /content/recsys/raw/train.parquet
# [load] 2,000,000 rows  |  CTR=0.0513
# [split] train=1,800,545  valid=199,455
# [vocab] building...
